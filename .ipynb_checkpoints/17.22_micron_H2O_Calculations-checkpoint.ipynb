# %%
# %pylab inline
from astropy.io import fits
import astropy.units as u
import pickle as pickle
import os as os
import pandas as pd

from spec_utils import read_irs

from spectools_ir.utils import extract_hitran_data, spec_convol, make_rotation_diagram, get_molmass
from spectools_ir.utils import compute_thermal_velocity, sigma_to_fwhm, fwhm_to_sigma, wn_to_k, spec_convol_R
from spectools_ir.utils import get_miri_mrs_resolution, get_miri_mrs_wavelengths, make_miri_mrs_figure

from spectools_ir.flux_calculator import calc_fluxes, make_lineshape

from spectools_ir.slabspec import make_spec

from spectools_ir.slab_fitter import Config, LineData,Retrieval
from spectools_ir.slab_fitter import corner_plot, trace_plot, find_best_fit, compute_model_fluxes
from spectools_ir.slab_fitter import calc_solid_angle, calc_radius
from spectools_ir.slab_fitter import read_data_from_file, get_samples
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Targets that should work for the code:
# ### HT Lup, GW Lup, IM Lup, RU Lup, AS 205, DoAr 25, WaOph 6, AS 209, FZ Tau, TW Cha, VZ Cha, GQ Lup, IRAS 04385, GK Tau, CI Tau, RY Lup

# %% [markdown]
# ### Upper limits for: HT Lup, GW Lup, IM Lup, DoAr 25, RY Lup

# %% [markdown]
# ### Shapes error for IQ Tau and line fitting error with HD163296

# %%
#HT Lup

irs=read_irs('HTLUP',dd='/Users/dougcobb/URSI_2022/REDUCED/',noerror=True)
wave_data = pd.DataFrame([17.22], columns=['wave'])
lineflux_data=calc_fluxes(irs.wave,irs.flux,wave_data,v_dop=200,fwhm_v=500.,sep_v=2500.,cont=0,vet_fits=True, plot=True,ymax=0.10, ymin=-0.01,amp=0.02)
#linefluxes.append(lineflux_data['lineflux'])

lineflux_data
# Out:
# Is this fit okay? [y or n]y
#     wave      lineflux  lineflux_Gaussian  lineflux_err   linewidth  \
# 0  17.22  7.934754e-18       7.585357e-18  5.708063e-18  436.468772
#
#    linewidth_err  v_dop_fit  v_dop_fit_err  continuum  continuum_err
# 0     495.970865  38.429421     179.112431   0.010756       0.005589

# %%
#GW Lup

irs=read_irs('GWLUP',dd='/Users/dougcobb/URSI_2022/REDUCED/',noerror=True)
wave_data = pd.DataFrame([17.22], columns=['wave'])
lineflux_data=calc_fluxes(irs.wave,irs.flux,wave_data,v_dop=200,fwhm_v=500.,sep_v=2500.,cont=0,vet_fits=True, plot=True,ymax=0.010, ymin=-0.01,amp=0.02)
#linefluxes.append(lineflux_data['lineflux'])

lineflux_data

#THIS ONE LOOKS WEIRDLY FLAT?
# Out:
# Is this fit okay? [y or n]n
# Empty DataFrame
# Columns: [wave, lineflux, lineflux_Gaussian, lineflux_err, linewidth, linewidth_err, v_dop_fit, v_dop_fit_err, continuum, continuum_err]
# Index: []

# %%
#IM Lup

irs=read_irs('IMLUP',dd='/Users/dougcobb/URSI_2022/REDUCED/',noerror=True)
wave_data = pd.DataFrame([17.22], columns=['wave'])
lineflux_data=calc_fluxes(irs.wave,irs.flux,wave_data,v_dop=200,fwhm_v=500.,sep_v=2500.,cont=0,vet_fits=True, plot=True,ymax=0.10, ymin=-0.01,amp=0.02)
#linefluxes.append(lineflux_data['lineflux'])

lineflux_data
# Out:
# Is this fit okay? [y or n]y
#     wave      lineflux  lineflux_Gaussian  lineflux_err   linewidth  \
# 0  17.22  2.945558e-18       3.139033e-18  2.021112e-18  759.913523
#
#    linewidth_err  v_dop_fit  v_dop_fit_err  continuum  continuum_err
# 0     524.693444 -74.477722     205.838615  -0.007893       0.001248

# %%
#RU Lup

irs=read_irs('RULUP',dd='/Users/dougcobb/URSI_2022/REDUCED/',noerror=True)
wave_data = pd.DataFrame([17.22], columns=['wave'])
lineflux_data=calc_fluxes(irs.wave,irs.flux,wave_data,v_dop=200,fwhm_v=500.,sep_v=2500.,cont=0,vet_fits=True, plot=True,ymax=0.10, ymin=-0.01,amp=0.02)
#linefluxes.append(lineflux_data['lineflux'])

lineflux_data
# Out:
# Is this fit okay? [y or n]y
#     wave      lineflux  lineflux_Gaussian  lineflux_err   linewidth  \
# 0  17.22  3.918422e-17       5.310724e-17  2.369011e-17  966.957311
#
#    linewidth_err   v_dop_fit  v_dop_fit_err  continuum  continuum_err
# 0     423.892678  165.754834     160.915787  -0.048534       0.012411

# %%
#AS 205

irs=read_irs('AS205_c2d',dd='/Users/dougcobb/URSI_2022/REDUCED/',noerror=True)
wave_data = pd.DataFrame([17.22], columns=['wave'])
lineflux_data=calc_fluxes(irs.wave,irs.flux,wave_data,v_dop=200,fwhm_v=500.,sep_v=2500.,cont=0,vet_fits=True, plot=True,ymax=0.50, ymin=-0.01,amp=0.02)
#linefluxes.append(lineflux_data['lineflux'])

lineflux_data
# Out:
# Is this fit okay? [y or n]n
# Empty DataFrame
# Columns: [wave, lineflux, lineflux_Gaussian, lineflux_err, linewidth, linewidth_err, v_dop_fit, v_dop_fit_err, continuum, continuum_err]
# Index: []

# %%
#DoAr 25

irs=read_irs('DOAR25',dd='/Users/dougcobb/URSI_2022/REDUCED/',noerror=True)
wave_data = pd.DataFrame([17.22], columns=['wave'])
lineflux_data=calc_fluxes(irs.wave,irs.flux,wave_data,v_dop=200,fwhm_v=500.,sep_v=2500.,cont=0,vet_fits=True, plot=True,ymax=0.10, ymin=-0.01,amp=0.02)
#linefluxes.append(lineflux_data['lineflux'])

lineflux_data
# Out:
# Is this fit okay? [y or n]y
#     wave      lineflux  lineflux_Gaussian  lineflux_err  linewidth  \
# 0  17.22  2.095959e-18       2.651590e-18  1.639666e-18  356.22243
#
#    linewidth_err  v_dop_fit  v_dop_fit_err  continuum  continuum_err
# 0     287.676198 -51.092269     151.494423   0.005818       0.001911

# %%
#WaOph 6

irs=read_irs('WAOPH6',dd='/Users/dougcobb/URSI_2022/REDUCED/',noerror=True)
wave_data = pd.DataFrame([17.22], columns=['wave'])
lineflux_data=calc_fluxes(irs.wave,irs.flux,wave_data,v_dop=200,fwhm_v=500.,sep_v=2500.,cont=0,vet_fits=True, plot=True,ymax=0.10, ymin=-0.01,amp=0.02)
#linefluxes.append(lineflux_data['lineflux'])

lineflux_data
# Out:
# Is this fit okay? [y or n]y
#     wave      lineflux  lineflux_Gaussian  lineflux_err   linewidth  \
# 0  17.22  8.099517e-18       7.884979e-18  3.476549e-18  404.147451
#
#    linewidth_err  v_dop_fit  v_dop_fit_err  continuum  continuum_err
# 0     306.031587  30.166067      98.909839   0.011442       0.003657

# %%
#AS209

irs=read_irs('V1121OPH',dd='/Users/dougcobb/URSI_2022/REDUCED/',noerror=True)
wave_data = pd.DataFrame([17.22], columns=['wave'])
lineflux_data=calc_fluxes(irs.wave,irs.flux,wave_data,v_dop=200,fwhm_v=500.,sep_v=2500.,cont=0,vet_fits=True, plot=True,ymax=0.10, ymin=-0.01,amp=0.02)
#linefluxes.append(lineflux_data['lineflux'])

lineflux_data
# Out:
# Is this fit okay? [y or n]n
# Empty DataFrame
# Columns: [wave, lineflux, lineflux_Gaussian, lineflux_err, linewidth, linewidth_err, v_dop_fit, v_dop_fit_err, continuum, continuum_err]
# Index: []

# %%
#HD 163296

irs=read_irs('HD163296',dd='/Users/dougcobb/URSI_2022/REDUCED/',noerror=True)
wave_data = pd.DataFrame([17.22], columns=['wave'])
lineflux_data=calc_fluxes(irs.wave,irs.flux,wave_data,v_dop=200,fwhm_v=500.,sep_v=2500.,cont=0,vet_fits=True, plot=True,ymax=0.10, ymin=-0.01,amp=0.02)
#linefluxes.append(lineflux_data['lineflux'])

lineflux_data
# Out:
# Is this fit okay? [y or n]n
# Empty DataFrame
# Columns: [wave, lineflux, lineflux_Gaussian, lineflux_err, linewidth, linewidth_err, v_dop_fit, v_dop_fit_err, continuum, continuum_err]
# Index: []

# %%
#FZ Tau

irs=read_irs('FZTAU',dd='/Users/dougcobb/URSI_2022/REDUCED/',noerror=True)
wave_data = pd.DataFrame([17.22], columns=['wave'])
lineflux_data=calc_fluxes(irs.wave,irs.flux,wave_data,v_dop=200,fwhm_v=500.,sep_v=2500.,cont=0,vet_fits=True, plot=True,ymax=0.10, ymin=-0.01,amp=0.02)
#linefluxes.append(lineflux_data['lineflux'])

lineflux_data
# Out:
# /Users/dougcobb/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# /Users/dougcobb/opt/anaconda3/lib/python3.9/site-packages/spectools_ir/flux_calculator/helpers.py:188: RuntimeWarning: Mean of empty slice
#   dwave=np.nanmean(np.diff(myx[mybool]))
# Is this fit okay? [y or n]n
# Empty DataFrame
# Columns: [wave, lineflux, lineflux_Gaussian, lineflux_err, linewidth, linewidth_err, v_dop_fit, v_dop_fit_err, continuum, continuum_err]
# Index: []

# %%
#TW Cha

irs=read_irs('TWCHA',dd='/Users/dougcobb/URSI_2022/REDUCED/',noerror=True)
wave_data = pd.DataFrame([17.22], columns=['wave'])
lineflux_data=calc_fluxes(irs.wave,irs.flux,wave_data,v_dop=200,fwhm_v=500.,sep_v=2500.,cont=0,vet_fits=True, plot=True,ymax=0.10, ymin=-0.01,amp=0.02)
#linefluxes.append(lineflux_data['lineflux'])

lineflux_data
# Out:
# Is this fit okay? [y or n]y
#     wave      lineflux  lineflux_Gaussian  lineflux_err  linewidth  \
# 0  17.22  5.480712e-18       5.853634e-18  2.073012e-18  368.68364
#
#    linewidth_err  v_dop_fit  v_dop_fit_err  continuum  continuum_err
# 0     216.875969  86.865548      82.021188   0.006765       0.002356

# %%
#VZ Cha

irs=read_irs('VZCHA',dd='/Users/dougcobb/URSI_2022/REDUCED/',noerror=True)
wave_data = pd.DataFrame([17.22], columns=['wave'])
lineflux_data=calc_fluxes(irs.wave,irs.flux,wave_data,v_dop=200,fwhm_v=500.,sep_v=2500.,cont=0,vet_fits=True, plot=True,ymax=0.10, ymin=-0.01,amp=0.02)
#linefluxes.append(lineflux_data['lineflux'])

lineflux_data
# Out:
# Is this fit okay? [y or n]y
#     wave      lineflux  lineflux_Gaussian  lineflux_err   linewidth  \
# 0  17.22  8.549667e-18       8.499238e-18  2.017569e-18  339.751064
#
#    linewidth_err  v_dop_fit  v_dop_fit_err  continuum  continuum_err
# 0     169.364854  81.969542      55.160467   0.013283        0.00248

# %%
#GQ Lup

irs=read_irs('GQLUP',dd='/Users/dougcobb/URSI_2022/REDUCED/',noerror=True)
wave_data = pd.DataFrame([17.22], columns=['wave'])
lineflux_data=calc_fluxes(irs.wave,irs.flux,wave_data,v_dop=200,fwhm_v=500.,sep_v=2500.,cont=0,vet_fits=True, plot=True,ymax=0.10, ymin=-0.01,amp=0.02)
#linefluxes.append(lineflux_data['lineflux'])

lineflux_data
# Out:
# Is this fit okay? [y or n]y
#     wave      lineflux  lineflux_Gaussian  lineflux_err   linewidth  \
# 0  17.22  6.125578e-18       7.170008e-18  2.807452e-18  319.336248
#
#    linewidth_err  v_dop_fit  v_dop_fit_err  continuum  continuum_err
# 0       230.7276  87.895927      103.11048    0.01533        0.00364

# %%
#IRAS 04385

irs=read_irs('04385+2550',dd='/Users/dougcobb/URSI_2022/REDUCED/',noerror=True)
wave_data = pd.DataFrame([17.22], columns=['wave'])
lineflux_data=calc_fluxes(irs.wave,irs.flux,wave_data,v_dop=200,fwhm_v=500.,sep_v=2500.,cont=0,vet_fits=True, plot=True,ymax=0.10, ymin=-0.01,amp=0.02)
#linefluxes.append(lineflux_data['lineflux'])

lineflux_data
# Out:
# Is this fit okay? [y or n]y
#     wave      lineflux  lineflux_Gaussian  lineflux_err   linewidth  \
# 0  17.22  3.958034e-18       4.438158e-18  2.225253e-18  332.263902
#
#    linewidth_err  v_dop_fit  v_dop_fit_err  continuum  continuum_err
# 0      397.32011   4.261646     114.870519   0.015968         0.0028

# %%
#GK Tau

irs=read_irs('GKTAU',dd='/Users/dougcobb/URSI_2022/REDUCED/',noerror=True)
wave_data = pd.DataFrame([17.22], columns=['wave'])
lineflux_data=calc_fluxes(irs.wave,irs.flux,wave_data,v_dop=200,fwhm_v=500.,sep_v=2500.,cont=0,vet_fits=True, plot=True,ymax=0.10, ymin=-0.1,amp=0.02)
#linefluxes.append(lineflux_data['lineflux'])

lineflux_data
# Out:
# Is this fit okay? [y or n]y
#     wave      lineflux  lineflux_Gaussian  lineflux_err   linewidth  \
# 0  17.22  8.852458e-18       8.816556e-18  3.314615e-18  400.306266
#
#    linewidth_err  v_dop_fit  v_dop_fit_err  continuum  continuum_err
# 0     241.199801  10.074968       86.40806  -0.021862       0.003503

# %%
#CI Tau

irs=read_irs('CITAU',dd='/Users/dougcobb/URSI_2022/REDUCED/',noerror=True)
wave_data = pd.DataFrame([17.22], columns=['wave'])
lineflux_data=calc_fluxes(irs.wave,irs.flux,wave_data,v_dop=200,fwhm_v=500.,sep_v=2500.,cont=0,vet_fits=True, plot=True,ymax=0.10, ymin=-0.01,amp=0.02)
#linefluxes.append(lineflux_data['lineflux'])

lineflux_data
# Out:
# Is this fit okay? [y or n]y
#     wave      lineflux  lineflux_Gaussian  lineflux_err   linewidth  \
# 0  17.22  9.310259e-18       1.012184e-17  2.867701e-18  431.380103
#
#    linewidth_err  v_dop_fit  v_dop_fit_err  continuum  continuum_err
# 0     180.948323  72.864104      67.539365   0.016948       0.002833

# %%
#RY Lup

irs=read_irs('RYLUP',dd='/Users/dougcobb/URSI_2022/REDUCED/',noerror=True)
wave_data = pd.DataFrame([17.22], columns=['wave'])
lineflux_data=calc_fluxes(irs.wave,irs.flux,wave_data,v_dop=200,fwhm_v=500.,sep_v=2500.,cont=0,vet_fits=True, plot=True,ymax=0.10, ymin=-0.1,amp=0.02)
#linefluxes.append(lineflux_data['lineflux'])

lineflux_data
# Out:
# Is this fit okay? [y or n]n
# Empty DataFrame
# Columns: [wave, lineflux, lineflux_Gaussian, lineflux_err, linewidth, linewidth_err, v_dop_fit, v_dop_fit_err, continuum, continuum_err]
# Index: []

# %%
#IQ Tau

irs=read_irs('IQTAU',dd='/Users/dougcobb/URSI_2022/REDUCED/',noerror=True)
wave_data = pd.DataFrame([17.22], columns=['wave'])
lineflux_data=calc_fluxes(irs.wave,irs.flux,wave_data,v_dop=200,fwhm_v=500.,sep_v=2500.,cont=0,vet_fits=True, plot=True,ymax=0.10, ymin=-0.01,amp=0.02)
#linefluxes.append(lineflux_data['lineflux'])

lineflux_data

#SHAPES ERROR
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/4c/_90ncs6j0gb05tr7c3125p400000gn/T/ipykernel_6206/1017825816.py in <module>
#       1 #IQ Tau
#       2
# ----> 3 irs=read_irs('IQTAU',dd='/Users/dougcobb/URSI_2022/REDUCED/',noerror=True)
#       4 wave_data = pd.DataFrame([17.22], columns=['wave'])
#       5 lineflux_data=calc_fluxes(irs.wave,irs.flux,wave_data,v_dop=200,fwhm_v=500.,sep_v=2500.,cont=0,vet_fits=True, plot=True,ymax=0.10, ymin=-0.01,amp=0.02)
#
# ~/mypy/spec_utils/spec_utils.py in read_irs(src_name, orderc, shflag, lhflag, silicate, ice, noerror, dd)
#     530         w2=(wave > 24.3) & (wave < 24.5)
#     531       if(np.sum(w2) > 0):
# --> 532         myw=(w & w2)
#     533         lspec2=spec[myw]
#     534         lwave=wave[myw]
#
# ValueError: operands could not be broadcast together with shapes (878,) (879,)
